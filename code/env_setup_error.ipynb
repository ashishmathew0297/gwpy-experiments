# %% [markdown]
# ### Recreating the environment setup errors
# Steps taken by me:
#
# - Run the conda env setup from the gengli repo with the only change being the environment name (seen below)
# ```bash
# conda create --name test_env python=3.9
# conda activate test_env
# git clone https://git.ligo.org/melissa.lopez/gengli.git
# cd gengli
# python setup.py sdist
# pip install dist/gengli-0.2.0.tar.gz
# ```
# - Install matplotlib
# ```bash
# conda install matplotlib
# ```
# - Run the code below

# %%
import gengli
import matplotlib.pyplot as plt
import numpy as np
from gwpy.timeseries import TimeSeries
from pycbc.noise import reproduceable
import pycbc.filter
from gengli.utils import compute_distance_matrix, metrics
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import gengli
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#
# File ~/miniconda3/envs/test_env/lib/python3.9/site-packages/gengli/__init__.py:9
#       1 """
#       2 gengli
#       3 ======
#    (...)
#       7
#       8 """
# ----> 9 from .glitch_generator import glitch_generator
#
# File ~/miniconda3/envs/test_env/lib/python3.9/site-packages/gengli/glitch_generator.py:10
#       8 import numpy as np
#       9 import time
# ---> 10 from .utils import compute_distance_matrix, resample_glitch, low_pass_glitch, rescale_glitch
#      11 import itertools
#      12 from tqdm import tqdm
#
# File ~/miniconda3/envs/test_env/lib/python3.9/site-packages/gengli/utils.py:5
#       1 """
# ...

# %% [markdown]
# The above error is different from what I received yesterday. I'll try to recreate that issue now
#
# - Installing gwpy with the following
# ```bash
# conda install -c conda-forge gwpy
# ```
# - Installing pycbc with `pip`
# ```bash
# pip install pycbc
# ```
# - Changed the order of imports so that gwpy comes first

# %%
from gwpy.timeseries import TimeSeries
from pycbc.noise import reproduceable
import gengli
import matplotlib.pyplot as plt
import numpy as np
import pycbc.filter
from gengli.utils import compute_distance_matrix, metrics
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from gwpy.timeseries import TimeSeries
#       2 from pycbc.noise import reproduceable
#       3 import gengli
#
# File ~/miniconda3/envs/test_env/lib/python3.9/site-packages/gwpy/timeseries/__init__.py:23
#      19 """Create, manipulate, read, and write time-series data
#      20 """
#      22 from .core import (TimeSeriesBase, TimeSeriesBaseDict, TimeSeriesBaseList)
# ---> 23 from .timeseries import (TimeSeries, TimeSeriesDict, TimeSeriesList)
#      24 from .statevector import (StateVector, StateVectorDict, StateVectorList,
#      25                           StateTimeSeries, StateTimeSeriesDict, Bits)
#      27 from . import io
#
# File ~/miniconda3/envs/test_env/lib/python3.9/site-packages/gwpy/timeseries/timeseries.py:27
#      25 import numpy
#      26 from numpy import fft as npfft
# ...

# %% [markdown]
# The same issue as above also shows up for pycbc.
#
# For some reason I'm not able to recreate the exact same error as before but the error text that had shown up for me when I first tried this installation and importing gwpy and pycbc was:
#
# ```python
# module 'numpy._core.umath' has no attribute '_ljust'
# ```
#
# which could have been due to the numpy version in the environment.
